# %% [markdown]
# ## Final Project Submission
#
# * Student name: Kezia Setokusumo
# * Student pace: Self-Paced
# * Scheduled project review date/time:
# * Instructor name: Mark Barbour
# * Blog post URL:

# %%
# Import pandas library and housing dataset
import pandas as pd
data=pd.read_csv('kc_house_data.csv', index_col=0)

# %%
# Inspect data
data.head()
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 7399300360   5/24/2022  675000.0         4        1.0         1180      7140
# 8910500230  12/13/2021  920000.0         5        2.5         2770      6703
# 1180000275   9/29/2021  311000.0         6        2.0         2880      6156
# 1604601802  12/14/2021  775000.0         3        3.0         2160      1400
# 8562780790   8/24/2021  592500.0         2        2.0         1120       758
#
#             floors waterfront greenbelt nuisance  ... sewer_system sqft_above  \
# id                                                ...
# 7399300360     1.0         NO        NO       NO  ...       PUBLIC       1180
# 8910500230     1.0         NO        NO      YES  ...       PUBLIC       1570
# 1180000275     1.0         NO        NO       NO  ...       PUBLIC       1580
# 1604601802     2.0         NO        NO       NO  ...       PUBLIC       1090
# 8562780790     2.0         NO        NO      YES  ...       PUBLIC       1120
#
#            sqft_basement sqft_garage sqft_patio  yr_built  yr_renovated  \
# id
# 7399300360             0           0         40      1969             0
# 8910500230          1570           0        240      1950             0
# 1180000275          1580           0          0      1956             0
# 1604601802          1070         200        270      2010             0
# 8562780790           550         550         30      2012             0
#
#                                                       address        lat  \
# id
# 7399300360  2102 Southeast 21st Court, Renton, Washington ...  47.461975
# 8910500230  11231 Greenwood Avenue North, Seattle, Washing...  47.711525
# 1180000275  8504 South 113th Street, Seattle, Washington 9...  47.502045
# 1604601802  4079 Letitia Avenue South, Seattle, Washington...  47.566110
# 8562780790  2193 Northwest Talus Drive, Issaquah, Washingt...  47.532470
#
#                  long
# id
# 7399300360 -122.19052
# 8910500230 -122.35591
# 1180000275 -122.22520
# 1604601802 -122.29020
# 8562780790 -122.07188
#
# [5 rows x 24 columns]

# %%
# Inspect columns
data.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'greenbelt', 'nuisance', 'view', 'condition',
#        'grade', 'heat_source', 'sewer_system', 'sqft_above', 'sqft_basement',
#        'sqft_garage', 'sqft_patio', 'yr_built', 'yr_renovated', 'address',
#        'lat', 'long'],
#       dtype='object')

# %%
data=data.dropna()

# %%
data['yr_built'].describe()
# Out:
# count    30111.000000
# mean      1975.162299
# std         32.052930
# min       1900.000000
# 25%       1953.000000
# 50%       1977.000000
# 75%       2003.000000
# max       2022.000000
# Name: yr_built, dtype: float64

# %%
data=data[data['yr_built']>=1980]
data
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 1604601802  12/14/2021   775000.0         3        3.0         2160      1400
# 8562780790   8/24/2021   592500.0         2        2.0         1120       758
# 7137850210   4/28/2022   820000.0         3        2.5         2214      3506
# 2944500680   3/17/2022   780000.0         4        2.5         2340      8125
# 2619950340   6/21/2021   975000.0         4        2.5         2980      5859
# ...                ...        ...       ...        ...          ...       ...
# 6142050730    6/3/2022  1325000.0         5        3.5         3100      6428
# 9376300851   10/7/2021   719000.0         3        2.5         1270      1141
# 194000695    6/16/2021  1313000.0         3        2.0         2020      5800
# 7960100080   5/27/2022   800000.0         3        2.0         1620      3600
# 2781280080   2/24/2022   775000.0         3        2.5         2570      2889
#
#             floors waterfront greenbelt nuisance  ... sewer_system sqft_above  \
# id                                                ...
# 1604601802     2.0         NO        NO       NO  ...       PUBLIC       1090
# 8562780790     2.0         NO        NO      YES  ...       PUBLIC       1120
# 7137850210     2.0         NO        NO       NO  ...       PUBLIC       2214
# 2944500680     2.0         NO        NO       NO  ...       PUBLIC       2340
# 2619950340     2.0         NO        NO       NO  ...       PUBLIC       2980
# ...            ...        ...       ...      ...  ...          ...        ...
# 6142050730     2.0         NO        NO       NO  ...       PUBLIC       3100
# 9376300851     2.0         NO        NO       NO  ...       PUBLIC       1050
# 194000695      2.0         NO        NO       NO  ...       PUBLIC       2020
# 7960100080     1.0         NO        NO      YES  ...       PUBLIC        940
# 2781280080     2.0         NO        NO       NO  ...       PUBLIC       1830
#
#            sqft_basement sqft_garage sqft_patio  yr_built  yr_renovated  \
# id
# 1604601802          1070         200        270      2010             0
# 8562780790           550         550         30      2012             0
# 7137850210             0         440        206      2019             0
# 2944500680             0         440         70      1989             0
# 2619950340             0         540        170      2011             0
# ...                  ...         ...        ...       ...           ...
# 6142050730             0         710        110      2018             0
# 9376300851           420         200         60      2007             0
# 194000695              0           0        520      2011             0
# 7960100080           920         240        110      1995             0
# 2781280080           740         480        100      2006             0
#
#                                                       address        lat  \
# id
# 1604601802  4079 Letitia Avenue South, Seattle, Washington...  47.566110
# 8562780790  2193 Northwest Talus Drive, Issaquah, Washingt...  47.532470
# 7137850210  24913 122nd Place Southeast, Kent, Washington ...  47.378355
# 2944500680  2721 Southwest 343rd Place, Federal Way, Washi...  47.293770
# 2619950340  27950 Northeast 147th Circle, Duvall, Washingt...  47.733170
# ...                                                       ...        ...
# 6142050730  28910 Northeast 156th Street, Duvall, Washingt...  47.740145
# 9376300851  8359 11th Avenue Northwest, Seattle, Washingto...  47.690440
# 194000695   4131 44th Avenue Southwest, Seattle, Washingto...  47.565610
# 7960100080  910 Martin Luther King Jr Way, Seattle, Washin...  47.610395
# 2781280080  17127 114th Avenue Southeast, Renton, Washingt...  47.449490
#
#                   long
# id
# 1604601802 -122.290200
# 8562780790 -122.071880
# 7137850210 -122.178625
# 2944500680 -122.369320
# 2619950340 -121.965305
# ...                ...
# 6142050730 -121.952390
# 9376300851 -122.370620
# 194000695  -122.388510
# 7960100080 -122.295850
# 2781280080 -122.189080
#
# [14126 rows x 24 columns]

# %%
# Make the data more interpretable later by subtracting the mean from 'sqft_living'
data['sqft_living']=data['sqft_living']-data['sqft_living'].mean()

# %%
data.hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'bathrooms'}>,
#         <AxesSubplot:title={'center':'sqft_living'}>],
#        [<AxesSubplot:title={'center':'sqft_lot'}>,
#         <AxesSubplot:title={'center':'floors'}>,
#         <AxesSubplot:title={'center':'sqft_above'}>,
#         <AxesSubplot:title={'center':'sqft_basement'}>],
#        [<AxesSubplot:title={'center':'sqft_garage'}>,
#         <AxesSubplot:title={'center':'sqft_patio'}>,
#         <AxesSubplot:title={'center':'yr_built'}>,
#         <AxesSubplot:title={'center':'yr_renovated'}>],
#        [<AxesSubplot:title={'center':'lat'}>,
#         <AxesSubplot:title={'center':'long'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
# Look at correlations and identify a highly correlated predictor to create the baseline model
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
heatmap=sns.heatmap(data.corr(), annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', pad=12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
# Import statsmodels for regression analysis
import statsmodels.api as sm
# Create a baseline model with 'price' as the dependent variable and 'sqft_living' as independent variable
y=data['price']
X=data[['sqft_living']]
baseline=sm.OLS(y, sm.add_constant(X))
baseline_results=baseline.fit()
# Display baseline model's summary statistics
print(baseline_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.405
# Model:                            OLS   Adj. R-squared:                  0.405
# Method:                 Least Squares   F-statistic:                     9616.
# Date:                Sat, 11 Mar 2023   Prob (F-statistic):               0.00
# Time:                        19:09:32   Log-Likelihood:            -2.1177e+05
# No. Observations:               14126   AIC:                         4.235e+05
# Df Residuals:                   14124   BIC:                         4.236e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1.223e+06   6600.198    185.237      0.000    1.21e+06    1.24e+06
# sqft_living   609.2048      6.213     98.059      0.000     597.027     621.382
# ==============================================================================
# Omnibus:                    21552.244   Durbin-Watson:                   1.806
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         31151969.336
# Skew:                           9.101   Prob(JB):                         0.00
# Kurtosis:                     232.338   Cond. No.                     1.06e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.06e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Interpret the results
"""40.5% of the variation is explained by the baseline model. However, the p-values for the y-intercept and sqft_living are statistically significant. The overall model is also statistically significant as its p-value is less than 0.05. The coefficient for sqft_living indicates that every unit increase of living area SF results in a $609 increase in home value."""
# Out:
# '40.5% of the variation is explained by the baseline model. However, the p-values for the y-intercept and sqft_living are statistically significant. The overall model is also statistically significant as its p-value is less than 0.05. The coefficient for sqft_living indicates that every unit increase of living area SF results in a $609 increase in home value.'

# %%
# Visualize the baseline model
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(X, y)
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
ax.set_xlabel("Living Area SF")
ax.set_ylabel("Home Price")
ax.set_title("Baseline Model Visualization")
# Out:
# Text(0.5, 1.0, 'Baseline Model Visualization')

# %%
# Expand simple linear regression baseline model to a multiple linear regression model
# Add another numerical predictor ('bathrooms')
data['bathrooms']=data['bathrooms']-data['bathrooms'].mean()
X_second = data[['sqft_living', 'bathrooms']]
X_second
# Out:
#             sqft_living  bathrooms
# id
# 1604601802  -257.532352   0.263309
# 8562780790 -1297.532352  -0.736691
# 7137850210  -203.532352  -0.236691
# 2944500680   -77.532352  -0.236691
# 2619950340   562.467648  -0.236691
# ...                 ...        ...
# 6142050730   682.467648   0.763309
# 9376300851 -1147.532352  -0.236691
# 194000695   -397.532352  -0.736691
# 7960100080  -797.532352  -0.736691
# 2781280080   152.467648  -0.236691
#
# [14126 rows x 2 columns]

# %%
# Create the second model
second=sm.OLS(y, sm.add_constant(X_second))
second_results=second.fit()
print(second_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.410
# Model:                            OLS   Adj. R-squared:                  0.410
# Method:                 Least Squares   F-statistic:                     4911.
# Date:                Sat, 11 Mar 2023   Prob (F-statistic):               0.00
# Time:                        19:09:32   Log-Likelihood:            -2.1171e+05
# No. Observations:               14126   AIC:                         4.234e+05
# Df Residuals:                   14123   BIC:                         4.234e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1.223e+06   6571.736    186.039      0.000    1.21e+06    1.24e+06
# sqft_living   530.5193      9.400     56.440      0.000     512.095     548.944
# bathrooms    1.428e+05   1.28e+04     11.118      0.000    1.18e+05    1.68e+05
# ==============================================================================
# Omnibus:                    21527.306   Durbin-Watson:                   1.804
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         30978841.951
# Skew:                           9.080   Prob(JB):                         0.00
# Kurtosis:                     231.699   Cond. No.                     2.08e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.08e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Create a dataframe of home grades to inspect values
grade_data=data['grade'].copy()
grade_data=pd.get_dummies(grade_data, columns=['grade'])
grade_data
# Out:
#             10 Very Good  11 Excellent  12 Luxury  13 Mansion  2 Substandard  \
# id
# 1604601802             0             0          0           0              0
# 8562780790             0             0          0           0              0
# 7137850210             0             0          0           0              0
# 2944500680             0             0          0           0              0
# 2619950340             0             0          0           0              0
# ...                  ...           ...        ...         ...            ...
# 6142050730             0             0          0           0              0
# 9376300851             0             0          0           0              0
# 194000695              0             0          0           0              0
# 7960100080             0             0          0           0              0
# 2781280080             0             0          0           0              0
#
#             4 Low  5 Fair  6 Low Average  7 Average  8 Good  9 Better
# id
# 1604601802      0       0              0          0       0         1
# 8562780790      0       0              0          1       0         0
# 7137850210      0       0              0          0       1         0
# 2944500680      0       0              0          0       1         0
# 2619950340      0       0              0          0       1         0
# ...           ...     ...            ...        ...     ...       ...
# 6142050730      0       0              0          0       1         0
# 9376300851      0       0              0          0       1         0
# 194000695       0       0              0          1       0         0
# 7960100080      0       0              0          1       0         0
# 2781280080      0       0              0          0       1         0
#
# [14126 rows x 11 columns]

# %%
# Create another dataframe with the categorical predictor 'grade' and conduct one-hot-encoding
X_third=data[['sqft_living', 'bathrooms', 'grade']]
X_third=pd.get_dummies(X_third, columns=['grade'])
# Drop 'grade_7 Average' to make it the reference category
X_third.drop(columns=['grade_7 Average'], inplace=True)
X_third
# Out:
#             sqft_living  bathrooms  grade_10 Very Good  grade_11 Excellent  \
# id
# 1604601802  -257.532352   0.263309                   0                   0
# 8562780790 -1297.532352  -0.736691                   0                   0
# 7137850210  -203.532352  -0.236691                   0                   0
# 2944500680   -77.532352  -0.236691                   0                   0
# 2619950340   562.467648  -0.236691                   0                   0
# ...                 ...        ...                 ...                 ...
# 6142050730   682.467648   0.763309                   0                   0
# 9376300851 -1147.532352  -0.236691                   0                   0
# 194000695   -397.532352  -0.736691                   0                   0
# 7960100080  -797.532352  -0.736691                   0                   0
# 2781280080   152.467648  -0.236691                   0                   0
#
#             grade_12 Luxury  grade_13 Mansion  grade_2 Substandard  \
# id
# 1604601802                0                 0                    0
# 8562780790                0                 0                    0
# 7137850210                0                 0                    0
# 2944500680                0                 0                    0
# 2619950340                0                 0                    0
# ...                     ...               ...                  ...
# 6142050730                0                 0                    0
# 9376300851                0                 0                    0
# 194000695                 0                 0                    0
# 7960100080                0                 0                    0
# 2781280080                0                 0                    0
#
#             grade_4 Low  grade_5 Fair  grade_6 Low Average  grade_8 Good  \
# id
# 1604601802            0             0                    0             0
# 8562780790            0             0                    0             0
# 7137850210            0             0                    0             1
# 2944500680            0             0                    0             1
# 2619950340            0             0                    0             1
# ...                 ...           ...                  ...           ...
# 6142050730            0             0                    0             1
# 9376300851            0             0                    0             1
# 194000695             0             0                    0             0
# 7960100080            0             0                    0             0
# 2781280080            0             0                    0             1
#
#             grade_9 Better
# id
# 1604601802               1
# 8562780790               0
# 7137850210               0
# 2944500680               0
# 2619950340               0
# ...                    ...
# 6142050730               0
# 9376300851               0
# 194000695                0
# 7960100080               0
# 2781280080               0
#
# [14126 rows x 12 columns]

# %%
# Create the third model with 'grade' as the sole categorical predictor
third=sm.OLS(y, sm.add_constant(X_third))
third_results=third.fit()
print(third_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.510
# Model:                            OLS   Adj. R-squared:                  0.509
# Method:                 Least Squares   F-statistic:                     1222.
# Date:                Sat, 11 Mar 2023   Prob (F-statistic):               0.00
# Time:                        19:09:32   Log-Likelihood:            -2.1041e+05
# No. Observations:               14126   AIC:                         4.208e+05
# Df Residuals:                   14113   BIC:                         4.209e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                9.273e+05   1.35e+04     68.719      0.000    9.01e+05    9.54e+05
# sqft_living           249.8627     10.294     24.274      0.000     229.686     270.040
# bathrooms            1.375e+05   1.18e+04     11.652      0.000    1.14e+05    1.61e+05
# grade_10 Very Good   9.036e+05   2.89e+04     31.223      0.000    8.47e+05     9.6e+05
# grade_11 Excellent   1.754e+06   4.61e+04     38.058      0.000    1.66e+06    1.84e+06
# grade_12 Luxury      2.875e+06    7.7e+04     37.311      0.000    2.72e+06    3.03e+06
# grade_13 Mansion     4.555e+06   1.72e+05     26.514      0.000    4.22e+06    4.89e+06
# grade_2 Substandard  1.257e+05   7.13e+05      0.176      0.860   -1.27e+06    1.52e+06
# grade_4 Low           1.02e+05   5.04e+05      0.202      0.840   -8.86e+05    1.09e+06
# grade_5 Fair         3.325e+05   2.26e+05      1.471      0.141    -1.1e+05    7.75e+05
# grade_6 Low Average  1.397e+05   5.74e+04      2.434      0.015    2.72e+04    2.52e+05
# grade_8 Good         1.328e+05   1.58e+04      8.423      0.000    1.02e+05    1.64e+05
# grade_9 Better       4.247e+05   1.99e+04     21.347      0.000    3.86e+05    4.64e+05
# ==============================================================================
# Omnibus:                    21897.633   Durbin-Watson:                   1.777
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         38131662.949
# Skew:                           9.339   Prob(JB):                         0.00
# Kurtosis:                     256.844   Cond. No.                     1.26e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.26e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Interpret the results of the third model
'''Homes with grades 2 to 6 inclusive are not statistically significant, as p-values are <0.05. This suggests that for homes of substandard to low average quality, there is an insignificant impact on the selling price, which makes sense in this scenario. Since we dropped grade_7 Average and used it as the reference category, the model indicates that a home with an average grade, average living area, and average number of bathrooms sells for around $927K (the constant). Additionally, a unit increase in "sqft_living" and "bathrooms" is expected to increase the value of the average home by $250 and $138K, respectively. Overall, the third model accounts for 51% of the variance in price.'''
# Out:
# 'Homes with grades 2 to 6 inclusive are not statistically significant, as p-values are <0.05. This suggests that for homes of substandard to low average quality, there is an insignificant impact on the selling price, which makes sense in this scenario. Since we dropped grade_7 Average and used it as the reference category, the model indicates that a home with an average grade, average living area, and average number of bathrooms sells for around $927K (the constant). Additionally, a unit increase in "sqft_living" and "bathrooms" is expected to increase the value of the average home by $250 and $138K, respectively. Overall, the third model accounts for 51% of the variance in price.'

# %%
# Additional one-hot-encoding with two more categorical variables ('waterfront' and 'sewer_system')
X_fourth=data[['sqft_living', 'bathrooms', 'grade', 'waterfront', 'sewer_system']]
X_fourth=pd.get_dummies(X_fourth, columns=['grade', 'waterfront', 'sewer_system'])
# Drop the columns with grade 2-6 since we know from the previous run that these variables
#  do not make a statistically significant difference
X_fourth=X_fourth.drop(columns=['grade_2 Substandard', 'grade_4 Low', 'grade_5 Fair', 'grade_6 Low Average'])
# Drop the columns below to make them the reference category
X_fourth.drop(columns=['grade_7 Average', 'waterfront_NO','sewer_system_PUBLIC'], inplace=True)
fourth=sm.OLS(y, sm.add_constant(X_fourth))
fourth_results=fourth.fit()
print(fourth_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.535
# Model:                            OLS   Adj. R-squared:                  0.535
# Method:                 Least Squares   F-statistic:                     1356.
# Date:                Sat, 11 Mar 2023   Prob (F-statistic):               0.00
# Time:                        19:09:32   Log-Likelihood:            -2.1002e+05
# No. Observations:               14126   AIC:                         4.201e+05
# Df Residuals:                   14113   BIC:                         4.202e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                            9.407e+05   1.32e+04     71.250      0.000    9.15e+05    9.67e+05
# sqft_living                       254.8570     10.215     24.949      0.000     234.834     274.880
# bathrooms                        1.225e+05   1.16e+04     10.557      0.000    9.97e+04    1.45e+05
# grade_10 Very Good               8.801e+05   2.81e+04     31.282      0.000    8.25e+05    9.35e+05
# grade_11 Excellent               1.681e+06   4.49e+04     37.431      0.000    1.59e+06    1.77e+06
# grade_12 Luxury                  2.691e+06   7.53e+04     35.749      0.000    2.54e+06    2.84e+06
# grade_13 Mansion                 4.307e+06   1.67e+05     25.724      0.000    3.98e+06    4.63e+06
# grade_8 Good                     1.211e+05   1.52e+04      7.984      0.000    9.14e+04    1.51e+05
# grade_9 Better                   4.179e+05   1.93e+04     21.703      0.000     3.8e+05    4.56e+05
# waterfront_YES                   1.484e+06   5.35e+04     27.719      0.000    1.38e+06    1.59e+06
# sewer_system_PRIVATE            -1.504e+05   1.85e+04     -8.108      0.000   -1.87e+05   -1.14e+05
# sewer_system_PRIVATE RESTRICTED   1.37e+05   4.91e+05      0.279      0.780   -8.25e+05     1.1e+06
# sewer_system_PUBLIC RESTRICTED  -7.186e+04      4e+05     -0.179      0.858   -8.57e+05    7.13e+05
# ==============================================================================
# Omnibus:                    20994.710   Durbin-Watson:                   1.763
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         30692746.253
# Skew:                           8.595   Prob(JB):                         0.00
# Kurtosis:                     230.709   Cond. No.                     8.94e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.94e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Interpret results of the fourth model
'''The fourth model accounts for ~54% of the variance in sale price and models against a reference home with the following features: (1)Average living area; (2) Average number of bathrooms; (3) Home grade of 7 (average); (4) No waterfront; (5)A public sewer system. Based on the constant coefficient, a home with the aforementioned features can be expected to have a sale price around $941K. With the additional variables, homes with restricted sewer systems lack a statistically significant impact. Of the additional variables, "waterfront_YES" and "sewer_system_PRIVATE" have p-values < 0.05, and they are associated with a $1.45M and -$150K change in sale price, respectively.'''
# Out:
# 'The fourth model accounts for ~54% of the variance in sale price and models against a reference home with the following features: (1)Average living area; (2) Average number of bathrooms; (3) Home grade of 7 (average); (4) No waterfront; (5)A public sewer system. Based on the constant coefficient, a home with the aforementioned features can be expected to have a sale price around $941K. With the additional variables, homes with restricted sewer systems lack a statistically significant impact. Of the additional variables, "waterfront_YES" and "sewer_system_PRIVATE" have p-values < 0.05, and they are associated with a $1.45M and -$150K change in sale price, respectively.'

# %%
# Visualize 'sqft_living' vs. 'price' and make the color hues based on 'grade' using seaborn
import seaborn as sns
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15,5))
sns.scatterplot(x=data['sqft_living'], y=data['price'], hue=data['grade'], data=data, palette='magma', ax=ax1)
ax1.set_title('Hue Based on "grade"', fontsize=20)
# The same visualization is run, with hues based on 'sewer_system'
sns.scatterplot(x=data['sqft_living'], y=data['price'], hue=data['sewer_system'], data=data, palette='pastel', ax=ax2)
ax2.set(ylabel=None)
ax2.tick_params(left=False)
ax2.set(yticklabels=[])
ax2.set_title('Hue Based on "sewer_system"', fontsize=20)
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)

# %%
'''Based on the visualization, homes with low grades tend to be clustered around the bottom left of the graph while homes with higher grades are more spread out, displaying a more positive relationship between living area and price. The visualization supports the summary statistics in the fourth model, which indicate that homes with low grades are statistically insignificant on home prices.'''
# Out:
# 'Based on the visualization, homes with low grades tend to be clustered around the bottom left of the graph while homes with higher grades are more spread out, displaying a more positive relationship between living area and price. The visualization supports the summary statistics in the fourth model, which indicate that homes with low grades are statistically insignificant on home prices.'

# %%
# Summary of regressions that have been run
summary_table=pd.DataFrame({'Model': [], 'Independent Variables':[], 'R-squared':[],
                                'Adj R-squared':[]})
summary_table.loc[0]=('Baseline Model', 'sqft_living', baseline_results.rsquared, baseline_results.rsquared_adj)
summary_table.loc[1]=('Second Model', 'sqft_living, bathrooms', second_results.rsquared, second_results.rsquared_adj)
summary_table.loc[2]=('Third Model', 'sqft_living, bathrooms, grade', third_results.rsquared, third_results.rsquared_adj)
summary_table.loc[3]=('Fourth Model', 'sqft_living, bathrooms, grade, waterfront, sewer_system', fourth_results.rsquared, fourth_results.rsquared_adj)
pd.set_option('max_colwidth', 90)
summary_table
# Out:
#             Model                                    Independent Variables  \
# 0  Baseline Model                                              sqft_living
# 1    Second Model                                   sqft_living, bathrooms
# 2     Third Model                            sqft_living, bathrooms, grade
# 3    Fourth Model  sqft_living, bathrooms, grade, waterfront, sewer_system
#
#    R-squared  Adj R-squared
# 0   0.405043       0.405001
# 1   0.410205       0.410121
# 2   0.509554       0.509137
# 3   0.535455       0.535060

# %%
X_no_interaction = data[['sqft_living', 'grade', 'bathrooms', 'waterfront', 'sewer_system']].copy()
X_no_interaction = pd.get_dummies(X_no_interaction, columns=['grade', 'waterfront', 'sewer_system'])
X_no_interaction.drop(columns=['grade_7 Average', 'waterfront_NO','sewer_system_PUBLIC'], inplace=True)
X_interaction=X_no_interaction.copy()
X_interaction["sqft_living x sewer_system_PRIVATE"] = X_interaction["sqft_living"] * X_interaction["sewer_system_PRIVATE"] 
X_interaction["sqft_living x bathrooms"] = X_interaction["sqft_living"] * X_interaction["bathrooms"]
X_interaction["sqft_living x grade_8 Good"] = X_interaction["sqft_living"] * X_interaction["grade_8 Good"]
X_interaction["sqft_living x waterfront_YES"] = X_interaction["sqft_living"] * X_interaction["waterfront_YES"]
X_interaction
# Out:
#             sqft_living  bathrooms  grade_10 Very Good  grade_11 Excellent  \
# id
# 1604601802  -257.532352   0.263309                   0                   0
# 8562780790 -1297.532352  -0.736691                   0                   0
# 7137850210  -203.532352  -0.236691                   0                   0
# 2944500680   -77.532352  -0.236691                   0                   0
# 2619950340   562.467648  -0.236691                   0                   0
# ...                 ...        ...                 ...                 ...
# 6142050730   682.467648   0.763309                   0                   0
# 9376300851 -1147.532352  -0.236691                   0                   0
# 194000695   -397.532352  -0.736691                   0                   0
# 7960100080  -797.532352  -0.736691                   0                   0
# 2781280080   152.467648  -0.236691                   0                   0
#
#             grade_12 Luxury  grade_13 Mansion  grade_2 Substandard  \
# id
# 1604601802                0                 0                    0
# 8562780790                0                 0                    0
# 7137850210                0                 0                    0
# 2944500680                0                 0                    0
# 2619950340                0                 0                    0
# ...                     ...               ...                  ...
# 6142050730                0                 0                    0
# 9376300851                0                 0                    0
# 194000695                 0                 0                    0
# 7960100080                0                 0                    0
# 2781280080                0                 0                    0
#
#             grade_4 Low  grade_5 Fair  grade_6 Low Average  grade_8 Good  \
# id
# 1604601802            0             0                    0             0
# 8562780790            0             0                    0             0
# 7137850210            0             0                    0             1
# 2944500680            0             0                    0             1
# 2619950340            0             0                    0             1
# ...                 ...           ...                  ...           ...
# 6142050730            0             0                    0             1
# 9376300851            0             0                    0             1
# 194000695             0             0                    0             0
# 7960100080            0             0                    0             0
# 2781280080            0             0                    0             1
#
#             grade_9 Better  waterfront_YES  sewer_system_PRIVATE  \
# id
# 1604601802               1               0                     0
# 8562780790               0               0                     0
# 7137850210               0               0                     0
# 2944500680               0               0                     0
# 2619950340               0               0                     0
# ...                    ...             ...                   ...
# 6142050730               0               0                     0
# 9376300851               0               0                     0
# 194000695                0               0                     0
# 7960100080               0               0                     0
# 2781280080               0               0                     0
#
#             sewer_system_PRIVATE RESTRICTED  sewer_system_PUBLIC RESTRICTED  \
# id
# 1604601802                                0                               0
# 8562780790                                0                               0
# 7137850210                                0                               0
# 2944500680                                0                               0
# 2619950340                                0                               0
# ...                                     ...                             ...
# 6142050730                                0                               0
# 9376300851                                0                               0
# 194000695                                 0                               0
# 7960100080                                0                               0
# 2781280080                                0                               0
#
#             sqft_living x sewer_system_PRIVATE  sqft_living x bathrooms  \
# id
# 1604601802                                -0.0               -67.810533
# 8562780790                                -0.0               955.880675
# 7137850210                                -0.0                48.174318
# 2944500680                                -0.0                18.351226
# 2619950340                                 0.0              -133.131147
# ...                                        ...                      ...
# 6142050730                                 0.0               520.933556
# 9376300851                                -0.0               271.610818
# 194000695                                 -0.0               292.858588
# 7960100080                                -0.0               587.535071
# 2781280080                                 0.0               -36.087752
#
#             sqft_living x grade_8 Good  sqft_living x waterfront_YES
# id
# 1604601802                   -0.000000                          -0.0
# 8562780790                   -0.000000                          -0.0
# 7137850210                 -203.532352                          -0.0
# 2944500680                  -77.532352                          -0.0
# 2619950340                  562.467648                           0.0
# ...                                ...                           ...
# 6142050730                  682.467648                           0.0
# 9376300851                -1147.532352                          -0.0
# 194000695                    -0.000000                          -0.0
# 7960100080                   -0.000000                          -0.0
# 2781280080                  152.467648                           0.0
#
# [14126 rows x 20 columns]

# %%
interaction_model = sm.OLS(y, sm.add_constant(X_interaction))
interaction_results = interaction_model.fit()
pvalues_df = pd.DataFrame(interaction_results.pvalues, columns=["p-value"])
pvalues_df["p < 0.05"] = pvalues_df["p-value"] < 0.05
pvalues_df
# Out:
#                                           p-value  p < 0.05
# const                                0.000000e+00      True
# sqft_living                         4.446869e-138      True
# bathrooms                            1.429668e-10      True
# grade_10 Very Good                  2.428480e-161      True
# grade_11 Excellent                  3.819078e-228      True
# grade_12 Luxury                     1.268352e-172      True
# grade_13 Mansion                     4.920099e-74      True
# grade_2 Substandard                  5.132382e-01     False
# grade_4 Low                          3.116971e-01     False
# grade_5 Fair                         9.438450e-01     False
# grade_6 Low Average                  7.718239e-01     False
# grade_8 Good                         1.683244e-09      True
# grade_9 Better                       4.999831e-88      True
# waterfront_YES                       4.753817e-41      True
# sewer_system_PRIVATE                 6.390096e-01     False
# sewer_system_PRIVATE RESTRICTED      6.775344e-01     False
# sewer_system_PUBLIC RESTRICTED       8.276820e-01     False
# sqft_living x sewer_system_PRIVATE   2.360801e-78      True
# sqft_living x bathrooms              3.730464e-36      True
# sqft_living x grade_8 Good           2.838724e-18      True
# sqft_living x waterfront_YES         6.752178e-55      True

# %%
X_interaction2=X_interaction.copy()
X_interaction2=X_interaction2.drop(columns=['sqft_living x sewer_system_PRIVATE', 'sewer_system_PRIVATE RESTRICTED', 'sewer_system_PUBLIC RESTRICTED', 'grade_2 Substandard', 'grade_4 Low', 'grade_5 Fair', 'grade_6 Low Average'])
X_interaction2
# Out:
#             sqft_living  bathrooms  grade_10 Very Good  grade_11 Excellent  \
# id
# 1604601802  -257.532352   0.263309                   0                   0
# 8562780790 -1297.532352  -0.736691                   0                   0
# 7137850210  -203.532352  -0.236691                   0                   0
# 2944500680   -77.532352  -0.236691                   0                   0
# 2619950340   562.467648  -0.236691                   0                   0
# ...                 ...        ...                 ...                 ...
# 6142050730   682.467648   0.763309                   0                   0
# 9376300851 -1147.532352  -0.236691                   0                   0
# 194000695   -397.532352  -0.736691                   0                   0
# 7960100080  -797.532352  -0.736691                   0                   0
# 2781280080   152.467648  -0.236691                   0                   0
#
#             grade_12 Luxury  grade_13 Mansion  grade_8 Good  grade_9 Better  \
# id
# 1604601802                0                 0             0               1
# 8562780790                0                 0             0               0
# 7137850210                0                 0             1               0
# 2944500680                0                 0             1               0
# 2619950340                0                 0             1               0
# ...                     ...               ...           ...             ...
# 6142050730                0                 0             1               0
# 9376300851                0                 0             1               0
# 194000695                 0                 0             0               0
# 7960100080                0                 0             0               0
# 2781280080                0                 0             1               0
#
#             waterfront_YES  sewer_system_PRIVATE  sqft_living x bathrooms  \
# id
# 1604601802               0                     0               -67.810533
# 8562780790               0                     0               955.880675
# 7137850210               0                     0                48.174318
# 2944500680               0                     0                18.351226
# 2619950340               0                     0              -133.131147
# ...                    ...                   ...                      ...
# 6142050730               0                     0               520.933556
# 9376300851               0                     0               271.610818
# 194000695                0                     0               292.858588
# 7960100080               0                     0               587.535071
# 2781280080               0                     0               -36.087752
#
#             sqft_living x grade_8 Good  sqft_living x waterfront_YES
# id
# 1604601802                   -0.000000                          -0.0
# 8562780790                   -0.000000                          -0.0
# 7137850210                 -203.532352                          -0.0
# 2944500680                  -77.532352                          -0.0
# 2619950340                  562.467648                           0.0
# ...                                ...                           ...
# 6142050730                  682.467648                           0.0
# 9376300851                -1147.532352                          -0.0
# 194000695                    -0.000000                          -0.0
# 7960100080                   -0.000000                          -0.0
# 2781280080                  152.467648                           0.0
#
# [14126 rows x 13 columns]

# %%
interaction2_model=sm.OLS(y, sm.add_constant(X_interaction2))
interaction2_results=interaction2_model.fit()
pvalues_df = pd.DataFrame(interaction2_results.pvalues, columns=["p-value"])
pvalues_df["p < 0.05"] = pvalues_df["p-value"] < 0.05
pvalues_df
# Out:
#                                     p-value  p < 0.05
# const                          0.000000e+00      True
# sqft_living                   3.047193e-101      True
# bathrooms                      4.128305e-14      True
# grade_10 Very Good            1.489097e-155      True
# grade_11 Excellent            1.583817e-218      True
# grade_12 Luxury               4.027839e-169      True
# grade_13 Mansion               9.887627e-68      True
# grade_8 Good                   8.358225e-09      True
# grade_9 Better                 2.601227e-87      True
# waterfront_YES                 9.206563e-45      True
# sewer_system_PRIVATE           5.324064e-11      True
# sqft_living x bathrooms        1.279502e-23      True
# sqft_living x grade_8 Good     3.466035e-12      True
# sqft_living x waterfront_YES   5.531641e-54      True

# %%
print(interaction2_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.552
# Model:                            OLS   Adj. R-squared:                  0.551
# Method:                 Least Squares   F-statistic:                     1335.
# Date:                Sat, 11 Mar 2023   Prob (F-statistic):               0.00
# Time:                        19:11:54   Log-Likelihood:            -2.0977e+05
# No. Observations:               14126   AIC:                         4.196e+05
# Df Residuals:                   14112   BIC:                         4.197e+05
# Df Model:                          13
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                         9.237e+05   1.46e+04     63.377      0.000    8.95e+05    9.52e+05
# sqft_living                    272.9241     12.673     21.536      0.000     248.083     297.765
# bathrooms                     8.784e+04   1.16e+04      7.565      0.000    6.51e+04    1.11e+05
# grade_10 Very Good            8.271e+05   3.07e+04     26.907      0.000    7.67e+05    8.87e+05
# grade_11 Excellent            1.523e+06   4.74e+04     32.119      0.000    1.43e+06    1.62e+06
# grade_12 Luxury               2.208e+06   7.86e+04     28.102      0.000    2.05e+06    2.36e+06
# grade_13 Mansion              3.071e+06   1.76e+05     17.484      0.000    2.73e+06    3.42e+06
# grade_8 Good                  9.757e+04   1.69e+04      5.765      0.000    6.44e+04    1.31e+05
# grade_9 Better                4.144e+05   2.08e+04     19.946      0.000    3.74e+05    4.55e+05
# waterfront_YES                9.023e+05   6.41e+04     14.087      0.000    7.77e+05    1.03e+06
# sewer_system_PRIVATE         -1.201e+05   1.83e+04     -6.567      0.000   -1.56e+05   -8.43e+04
# sqft_living x bathrooms         38.5414      3.841     10.035      0.000      31.013      46.069
# sqft_living x grade_8 Good    -116.5500     16.737     -6.963      0.000    -149.357     -83.743
# sqft_living x waterfront_YES   487.9593     31.408     15.536      0.000     426.395     549.523
# ==============================================================================
# Omnibus:                    21302.003   Durbin-Watson:                   1.763
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         39308043.954
# Skew:                           8.771   Prob(JB):                         0.00
# Kurtosis:                     260.830   Cond. No.                     6.94e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.94e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
